# %% [markdown]
# # tailorsin.com - api's

# %% [markdown]
# ## fetch customer basic info

# %%
# --------------------------------
# Client Type Classification
# --------------------------------

import requests
url = "https://crm.tailorsin.com/tailorsin-api/api/getclient.php"


params = {
    "mobile": "7287874454"
}

response = requests.get(url, params=params)

print(response.status_code)
print(response.text)
# Out:
# 200
# {"status":"success","type":"client","type_label":"Client","description":"client exists but no active order currently","client":{"id":"42775","cname":"register","whatsapp":"917287874454","tel":"917287874454","salute":"","is_client":null,"city":"","add_date":"2026-07-26 10:51:52"}}

# %%
# --------------------------------
# fetch customer info
# --------------------------------

import requests

url = "https://crm.tailorsin.com/tailorsin-api/api/customerinfo.php"

payload = {
    "mobile": "7287874454"
}

response = requests.get(url, params=payload)

print(response.status_code)
print(response.text)      # Print raw response first
# Out:
# 200
# {"status":"success","customer":{"id":"42772","uid":null,"is_client":null,"toggle":null,"salute":"","b2b":"0","cname":"John Doe","dob":"0000-00-00","clgstin":"","tel":"917287874454","email":"johndoe@example.com","whatsapp":"917287874454","address":"","address2":"","locality":"","city":"","pincode":"","lat":"","lng":"","add_date":"2026-07-26 06:21:01","chat":null,"new_whatsapp":"0","last_spoken":null,"deleted":null,"otp_auth":null,"telcal":null,"fasdis":null,"on_quote":null,"welcome_sent":null,"brand":null,"website":null,"lang1":"","lang2":"","chatby":"","client_store_id":"0","clientsource":"","instaid":null,"contact_person":"","bank_ac_name":"","bank_ac_no":"","bank_ifsc":"","bank_address":"","isvendor":"0"},"addresses":[]}

# %%
# --------------------------------
# fetch garments 
# --------------------------------
import requests

url = "https://crm.tailorsin.com/tailorsin-api/api/items"

response = requests.get(url)

print(response.status_code)
print(response.text)
# Out:
# 200
# {"status":"success","count":102,"data":[{"id":"101","catid":"1","iname":"Alterations","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"145","catid":"1","iname":"Custom","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"106","catid":"1","iname":"Embroidery","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"149","catid":"1","iname":"Free Alterations","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"36","catid":"1","iname":"Measurement","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"42","catid":"1","iname":"Miscellaneous","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"10","catid":"1","iname":"MW - Coats\/Blazers\/Sherwani","deleted":null,"vstatus":"0","category_label":"Retail 24-25"},{"id":"63","catid":"1","iname":"MW - Kids (0-4)","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"64","catid":"1","iname":"MW - Kids (5-10)","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"61","catid":"1","iname":"MW - Pants","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"60","catid":"1","iname":"MW - Shirt\/Kurtha","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"35","catid":"1","iname":"Pending Confirmation","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"33","catid":"1","iname":"Returns","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"67","catid":"1","iname":"WW - Blouse","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"56","catid":"1","iname":"WW - Frock\/Gown","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"65","catid":"1","iname":"WW - Kids(0-4)","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"66","catid":"1","iname":"WW - Kids(5-10)","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"69","catid":"1","iname":"WW - Lehenga\/Skirt","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"58","catid":"1","iname":"WW - Pants","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"25","catid":"1","iname":"WW - Saree\/Dupatta","deleted":null,"vstatus":"0","category_label":"Retail 24-25"},{"id":"68","catid":"1","iname":"WW - Top","deleted":"0","vstatus":"0","category_label":"Retail 24-25"},{"id":"73","catid":"2","iname":"Alterations","deleted":"0","vstatus":"0","category_label":"B2B 24-25"},{"id":"74","catid":"2","iname":"Custom","deleted":"0","vstatus":"0","category_label":"B2B 24-25"},{"id":"75","catid":"2","iname":"Embroidery","deleted":"0","vstatus":"0","category_label":"B2B 24-25"},{"id":"76","catid":"2","iname":"Free Alterations","deleted":"0","vstatus":"0","category_label":"B2B 24-25"},{"id":"77","catid":"2","iname":"Measurement","deleted":"0","vstatus":"0","category_label":"B2B 24-25"},{"id":"78","catid":"2","iname":"Miscellaneous","deleted":"0","vstatus":"0","category_label":"B2B 24-25"},{"id":"79","catid":"2","iname":"MW - Coats\/Blazers\/Sherwani","deleted":"0","vstatus":"0","category_label":"B2B 24-25"},{"id":"80","catid":"2","iname":"MW - Kids (0-4)","deleted":"0","vstatus":"0","category_label":"B2B 24-25"},{"id":"81","catid":"2","iname":"MW - Kids (5-10)","deleted":"0","vstatus":"0","category_label":"B2B 24-25"},{"id":"82","catid":"2","iname":"MW - Pants","deleted":"0","vstatus":"0","category_label":"B2B 24-25"},{"id":"83","catid":"2","iname":"MW - Shirt\/Kurtha","deleted":"0","vstatus":"0","category_label":"B2B 24-25"},{"id":"146","catid":"2","iname":"Pending Confirmation","deleted":"0","vstatus":"0","category_label":"B2B 24-25"},{"id":"100","catid":"2","iname":"Returns","deleted":"0","vstatus":"0","category_label":"B2B 24-25"},{"id":"86","catid":"2","iname":"WW - Blouse","deleted":"0","vstatus":"0","category_label":"B2B 24-25"},{"id":"87","catid":"2","iname":"WW - Frock\/Gown","deleted":"0","vstatus":"0","category_label":"B2B 24-25"},{"id":"88","catid":"2","iname":"WW - Kids(0-4)","deleted":"0","vstatus":"0 ...

# %%
# --------------------------------
# fetch price catalogue
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api/api/itemswithprice.php?view=html"

# %%
# --------------------------------
# fetch measurements
# --------------------------------
"""
import requests

url = "https://crm.tailorsin.com/tailorsin-api/api/clientmeasurements.php?"

payload = {
    "mobile": "919908712226"
}

response = requests.get(url, json=payload)

print("Status Code:", response.status_code)
print("Response:", response.text)
"""

# %% [markdown]
# ## User registartion/delete/schedule visit

# %%
# --------------------------------
# Register a new client
# --------------------------------

import requests

url = "https://crm.tailorsin.com/tailorsin-api/api/addclient.php"

payload = {
    "mobile": "7287874454",
    "cname": "Veerendra Maddukuri",
    "email": "mad@gmail.com"

}

response = requests.post(url, json=payload)

print(response.status_code)
print(response.json())

# %%
# --------------------------------
# Remove client using phone no
# --------------------------------

import requests

url = "https://crm.tailorsin.com/tailorsin-api/api/deleteclient.php"

payload = {
    "mobile": "7287874454"
}

response = requests.post(url, json=payload)

print("Status Code:", response.status_code)
print("Response:", response.text)
# Out:
# Status Code: 200
# Response: {"status":"success","message":"client removed successfully","data":{"id":"42775","cname":"register","mobile":"917287874454","deleted":true}}

# %%
# --------------------------------
# Book a visit
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api/api/bookappointment.php"

payload =

{
  "mobile": "919908712226",
  "store_id": 1,
  "bookdate": "2026-07-10",
  "booktime": "11:00 AM - 12:00 PM"
}

response = requests.post(url, json=payload)

print("Status Code:", response.status_code)
print("Response:", response.text)

# %% [markdown]
# ## user address management

# %%
# --------------------------------
# fetch customer address
# --------------------------------

import requests

url = "https://crm.tailorsin.com/tailorsin-api/api/customeraddress.php"

params = {
    "mobile": "7287874454"
}

response = requests.get(url, params=params)

print("Status Code:", response.status_code)

if response.status_code == 200:
    try:
        addresses = response.json()
        print(addresses)
    except ValueError:
        print("Response is not JSON")
        print(response.text)
else:
    print(response.text)
# Out:
# Status Code: 200
# {'status': 'success', 'client': {'id': 42748, 'cname': 'Bumble bee', 'mobile': '917287874454'}, 'count': 2, 'addresses': [{'id': '4923', 'cid': '42748', 'adr_id': '99', 'address': '201, kasturi nilayam, go green colony, niknampur', 'address2': '', 'locality': '', 'city': 'Hyderabad', 'zone': None, 'pincode': '500081', 'lat': '17.389942', 'lng': '78.366067', 'tel': ''}, {'id': '4925', 'cid': '42748', 'adr_id': '98', 'address': '4-13, kotalopala street', 'address2': '', 'locality': '', 'city': 'Bendapudi', 'zone': None, 'pincode': '533406', 'lat': '17.2686054', 'lng': '82.3751619', 'tel': ''}]}

# %%
# --------------------------------
# add customer address
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api/api/addaddress.php"

params = {
    
    "mobile": "919701667788",
    "address": "Flat 302, Green Meadows",
    "address2": "Near Metro Station",
    "locality": "Kondapur",
    "city": "Hyderabad",
    "pincode": "500084"
}

response = requests.post(url, json=payload)

print("Status Code:", response.status_code)
print(response.text)

# %%
# --------------------------------
# delete customer address
# --------------------------------

import requests

url = "https://crm.tailorsin.com/tailorsin-api/api/deleteaddress.php"

payload = {
    "mobile": "7287874454",
    "address_id": 4924
}

response = requests.post(url, json=payload)

print("Status Code:", response.status_code)
print(response.text)
# Out:
# Status Code: 200
# {"status":"success","message":"address deleted successfully, you can add a new one anytime","client":{"id":42748,"cname":"Bumble bee","mobile":"917287874454"},"address_id":4924,"deleted_address":"4-13, kotalopala street"}

# %% [markdown]
# ## User - order management

# %%
# --------------------------------
# place a new order
# --------------------------------

import requests
url = "https://crm.tailorsin.com/tailorsin-api/api/schedulepickup.php"

payload = {
    "mobile": "7287874454", 
    "pickup_date": "2026-07-10", 
    "pickup_time": 1,
    "address_id": 4838
}

response = requests.post(url, json=payload)

print(response.status_code)
print(response.json())
# Out:
# 400
# {'status': 'error', 'message': 'address_id is required - fetch saved addresses via /api/customeraddress.php and have the client pick one'}

# %%
# --------------------------------
# place second order
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api//api/scheduleanotherpickup.php"
{
  "mobile": "919640864111",
  "pickup_date": "2026-07-15",
  "pickup_time": 1,
  "address_id": 4838
}

response = requests.post(url, json=payload)

print(response.status_code)
print(response.json())

# %%
# --------------------------------
# cancel order
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api/api/cancelorder.php"
payload = {
    "mobile": "919701667788", 
    "order_id": 13877, 
    "reason": "Changed my mind" 
}

response = requests.post(url, json=payload)

print(response.status_code)
print(response.json())
# Out:
# 200
# {'status': 'success', 'message': 'order cancelled successfully', 'data': {'order_id': 13877, 'client': {'id': '42593', 'cname': 'Veerendra Maddukuri', 'mobile': '919701667788'}, 'stage': 8, 'stage_label': 'Cancelled', 'reason': 'Changed my mind', 'cancelled_at': '2026-07-10 09:50:43'}}

# %%
# --------------------------------
# modify order
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api/api/modifyorder.php"


payload = {
    
    "mobile": "919640864111",
    "comment": "Please make the sleeves half instead of full",
    "order_id": 8842,
}

response = requests.get(url, params=payload)

print(response.status_code)
print(response.text)

# %%
# --------------------------------
# current order status
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api/api/orderstatus.php"


payload = {
    "mobile": "9701667788"
}

response = requests.get(url, params=payload)

print(response.status_code)
print(response.text)
# Out:
# 200
# {"status":"success","client":{"id":42617,"cname":"Veerendra Maddukuri","mobile":"919701667788"},"count":2,"orders":[{"order_id":13948,"order_date":"2026-07-25 12:20:51","stage":0,"stage_label":"order on pickup","picked_up":false,"pickup_date":"2026-07-26","pickup_time":"1","last_update_date":"2026-07-25 12:20:51"},{"order_id":13891,"order_date":"2026-07-12 05:47:45","stage":8,"stage_label":"customer cancel","picked_up":true,"pickup_date":"2026-07-13","pickup_time":"1","last_update_date":"2026-07-22 07:58:12"}],"alteration_count":5,"alterations":[{"log_id":38113,"order_id":13887,"order_stage":7,"order_stage_label":"finished","order_closed":true,"pickup_date":"2026-07-13","pickup_time":"2","pickup_time_label":"2PM - 9PM","status":0,"status_label":"Pending","last_update":"2026-07-12 09:01:20"},{"log_id":38112,"order_id":13887,"order_stage":7,"order_stage_label":"finished","order_closed":true,"pickup_date":"2026-07-13","pickup_time":"1","pickup_time_label":"9AM - 2PM","status":0,"status_label":"Pending","last_update":"2026-07-12 09:00:21"},{"log_id":38111,"order_id":13887,"order_stage":7,"order_stage_label":"finished","order_closed":true,"pickup_date":"2026-07-12","pickup_time":"2","pickup_time_label":"2PM - 9PM","status":0,"status_label":"Pending","last_update":"2026-07-12 07:06:51"},{"log_id":38090,"order_id":13886,"order_stage":8,"order_stage_label":"customer cancel","order_closed":true,"pickup_date":"2026-07-11","pickup_time":"1","pickup_time_label":"9AM - 2PM","status":0,"status_label":"Pending","last_update":"2026-07-10 18:24:52"},{"log_id":38088,"order_id":13885,"order_stage":8,"order_stage_label":"customer cancel","order_closed":true,"pickup_date":"2026-07-11","pickup_time":"1","pickup_time_label":"9AM - 2PM","status":0,"status_label":"Pending","last_update":"2026-07-10 17:48:15"}]}

# %%
# --------------------------------
# delivered orders
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api/api/deliveredorders.php?"

payload = {
    "mobile": "9701667788"

}

response = requests.get(url, params=payload)

print(response.status_code)
print(response.text)
# Out:
# 200
# {"status":"success","client":{"id":42617,"cname":"Veerendra Maddukuri","mobile":"919701667788"},"count":7,"orders":[{"order_id":13887,"order_date":"2026-07-10 18:26:08","stage":7,"stage_label":"finished","pickup_date":"2026-07-11","delivered_on":"2026-07-10 18:26:08"},{"order_id":13886,"order_date":"2026-07-10 18:00:31","stage":8,"stage_label":"customer cancel","pickup_date":"2026-07-11","delivered_on":"2026-07-10 18:21:52"},{"order_id":13885,"order_date":"2026-07-10 17:03:55","stage":8,"stage_label":"customer cancel","pickup_date":"2026-07-11","delivered_on":"2026-07-10 17:37:51"},{"order_id":13884,"order_date":"2026-07-10 16:57:43","stage":3,"stage_label":"des. talking","pickup_date":"2026-07-11","delivered_on":"2026-07-10 16:57:43"},{"order_id":13883,"order_date":"2026-07-10 16:56:21","stage":8,"stage_label":"customer cancel","pickup_date":"2026-07-11","delivered_on":"2026-07-10 17:47:19"},{"order_id":13882,"order_date":"2026-07-10 16:51:17","stage":8,"stage_label":"customer cancel","pickup_date":"2026-07-10","delivered_on":"2026-07-10 17:49:03"},{"order_id":13881,"order_date":"2026-07-10 16:49:43","stage":8,"stage_label":"customer cancel","pickup_date":"2026-07-10","delivered_on":"2026-07-10 18:00:10"}]}

# %%
import requests

# --------------------------------
# Get Alteration Eligible Orders
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api/api/alterationeligibleorders.php"

params = {
    "mobile": "919701667788"
}

response = requests.get(url, params=params)

print("Status Code:", response.status_code)

try:
    print(response.json())
except ValueError:
    print(response.text)
# Out:
# Status Code: 200
# {'status': 'success', 'client': {'id': 42617, 'cname': 'Veerendra Maddukuri', 'mobile': '919701667788'}, 'message': 'no orders currently eligible for alteration for this client', 'count': 0, 'orders': []}

# %%
import requests

# --------------------------------
# Alteration Pickup
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api/api/alterationpickup.php"

payload = {
    "mobile": "919701667788",
    "pickup_date": "2026-07-12",
    "pickup_time": 2,
    "address_id": 4916,
    "order_id": 13887,
    "notes": "Shorten sleeves by 1 inch"
}

response = requests.post(url, json=payload)

print("Status Code:", response.status_code)

try:
    print(response.json())
except ValueError:
    print(response.text)
# Out:
# Status Code: 200
# {'status': 'success', 'message': 'alteration pickup scheduled successfully for order #13887', 'data': {'log_id': 38111, 'order_id': 13887, 'order_stage': 7, 'order_stage_label': 'finished', 'order_closed': False, 'client': {'id': 42617, 'cname': 'Veerendra Maddukuri', 'whatsapp': '919701667788'}, 'pickup_date': '2026-07-12', 'pickup_time': 2, 'pickup_time_label': '2PM - 9PM', 'pickup_address': {'id': '4916', 'address': '201, kasturi nilayam, go green colony, Neknampur', 'address2': '', 'locality': '', 'city': 'Hyderabad', 'pincode': '500089', 'lat': '', 'lng': ''}, 'type': 'Alteration', 'notes': 'Shorten sleeves by 1 inch', 'status': 'Pending'}}

# %%
# --------------------------------
# drop off fabric
# --------------------------------
url = "https://crm.tailorsin.com/tailorsin-api/api/fabricdelivery.php"

payload =

{ "mobile": "919908712226", 
  "store_id": 1, 
  "notes": "3 meters of cotton fabric for a shirt" 
}

response = requests.post(url, params=payload)

print(response.status_code)
print(response.text)

# %% [markdown]
# ## Human handover

# %%
# --------------------------------
# human handover 
# --------------------------------

url = "https://crm.tailorsin.com/tailorsin-api/api/humanhandover.php"

payload = {
    "mobile": "919908712226"
}

response = requests.post(url, params=payload)

print(response.status_code)
print(response.text)
